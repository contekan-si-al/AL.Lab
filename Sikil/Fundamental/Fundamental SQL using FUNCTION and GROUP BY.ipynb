# %% [markdown]
# ## Database

# %%
# membuat koneksi

# %load_ext sql
# %sql sqlite://
# Out:
# 'Connected: @None'

# %% [markdown]
# #### Tabel **students**

# %%
# membuat tabel students
# %%sql 

CREATE TABLE if not exists students (
    `StudentID` INT,
    `FirstName` VARCHAR(11),
    `LastName` VARCHAR(10),
    `Email` VARCHAR(25),
    `Semester1` NUMERIC(5, 3),
    `Semester2` NUMERIC(5, 3),
    `MarkGrowth` NUMERIC(4, 3)
);
# Out:
#  * sqlite://
# Done.
# []

# %%
# mengisi nilai di tabel students
# %%sql 

INSERT INTO
    students
VALUES
    (
        1,
        'Jose',
        'Mohit',
        'Jose_Mohit@gmail.com',
        64.55,
        72.6,
        -8.05
    ),
    (
        2,
        'Lala',
        'Karlina',
        'lala_karlina@yahoo.com',
        72.85,
        65.35,
        7.5
    ),
    (
        3,
        'Sultan',
        'Hadi',
        'Sultan_Hadi@gmail.com',
        45.32,
        50.25,
        -4.93
    ),
    (
        4,
        'Jaya',
        'Usman',
        'jaya_usman@yahoo.com',
        86.73,
        77.4,
        9.33
    ),
    (
        5,
        'Anjali',
        'Wijaya',
        'anjali_wijaya@yahoo.com',
        92.25,
        90.75,
        1.5
    );
# Out:
#  * sqlite://
# 5 rows affected.
# []

# %% [markdown]
# #### Tabel **tr_penjualan**

# %%
# membuat tabel tr_penjualan
# %%sql

CREATE TABLE IF NOT EXISTS tr_penjualan (
    `kode_transaksi` VARCHAR(16),
    `kode_pelanggan` VARCHAR(16),
    `no_urut` INT,
    `kode_produk` VARCHAR(13),
    `nama_produk` VARCHAR(31),
    `qty` INT,
    `total` INT
);
# Out:
#  * sqlite://
# Done.
# []

# %%
# mengisi nilai di tabel tr_penjualan
# %%sql

INSERT INTO
    tr_penjualan
VALUES
    (
        'tr-001',
        'dqlabcust07',
        1,
        'prod-01',
        'Kotak Pensil DQLab',
        5,
        312500
    ),
    (
        'tr-001',
        'dqlabcust07',
        2,
        'prod-03',
        'Flash disk DQLab 32 GB',
        1,
        100000
    ),
    (
        'tr-001',
        'dqlabcust07',
        3,
        'prod-09',
        'Buku Planner Agenda DQLab',
        3,
        276000
    ),
    (
        'tr-001',
        'dqlabcust07',
        4,
        'prod-04',
        'Flashdisk DQLab 32 GB',
        3,
        120000
    ),
    (
        'tr-002',
        'dqlabcust01',
        1,
        'prod-03',
        'Gift Voucher DQLab 100rb',
        2,
        200000
    ),
    (
        'tr-002',
        'dqlabcust01',
        2,
        'prod-10',
        'Sticky Notes DQLab 500 sheets',
        4,
        220000
    ),
    (
        'tr-002',
        'dqlabcust01',
        3,
        'prod-07',
        'Tas Travel Organizer DQLab',
        1,
        48000
    ),
    (
        'tr-003',
        'dqlabcust03',
        1,
        'prod-02',
        'Flashdisk DQLab 64 GB',
        2,
        110000
    ),
    (
        'tr-004',
        'dqlabcust03',
        1,
        'prod-10',
        'Sticky Notes DQLab 500 sheets',
        5,
        275000
    ),
    (
        'tr-004',
        'dqlabcust03',
        2,
        'prod-04',
        'Flashdisk DQLab 32 GB',
        4,
        160000
    ),
    (
        'tr-005',
        'dqlabcust05',
        1,
        'prod-09',
        'Buku Planner Agenda DQLab',
        3,
        276000
    ),
    (
        'tr-005',
        'dqlabcust05',
        2,
        'prod-01',
        'Kotak Pensil DQLab',
        1,
        62500
    ),
    (
        'tr-005',
        'dqlabcust05',
        3,
        'prod-04',
        'Flashdisk DQLab 32 GB',
        2,
        80000
    ),
    (
        'tr-006',
        'dqlabcust02',
        1,
        'prod-05',
        'Gift Voucher DQLab 250rb',
        4,
        1000000
    ),
    (
        'tr-006',
        'dqlabcust02',
        2,
        'prod-08',
        'Gantungan Kunci DQLab',
        2,
        31600
    );
# Out:
#  * sqlite://
# 15 rows affected.
# []

# %% [markdown]
# #### Tabel **sales_retail_2019**

# %%
# membuat tabel sales_retail_2019
# %%sql

CREATE TABLE IF NOT EXISTS sales_retail_2019 (
  `order_id` INT,
  `order_date` DATETIME,
  `customer_id` INT,
  `city` VARCHAR(18),
  `province` VARCHAR(20),
  `product_id` VARCHAR(12),
  `brand` VARCHAR(9),
  `quantity` INT,
  `item_price` VARCHAR(12)
);
# Out:
#  * sqlite://
# Done.
# []

# %%
# %%sql
#
# INSERT INTO
#     sales_retail_2019
# VALUES
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P0648', 'BRAND_C', 4, '1934000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P3826', 'BRAND_V', 8, '604000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1508', 'BRAND_G', 12, '747000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P0520', 'BRAND_B', 12, '450000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1513', 'BRAND_G', 3, '1500000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P3911', 'BRAND_V', 3, '2095000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1780', 'BRAND_H', 3, '2095000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P3132', 'BRAND_S', 3, '1745000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1342', 'BRAND_F', 6, '1045000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P2556', 'BRAND_P', 6, '1045000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P2154', 'BRAND_M', 4, '1745000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1685', 'BRAND_H', 12, '747000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P3665', 'BRAND_S', 4, '2375000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P0219', 'BRAND_A', 8, '1045000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1680', 'BRAND_H', 12, '747000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1679', 'BRAND_H', 12, '747000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P2159', 'BRAND_M', 24, '310000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P3837', 'BRAND_V', 4, '1500000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P2783', 'BRAND_P', 2, '555000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1255', 'BRAND_E', 3, '1500000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1118', 'BRAND_D', 4, '2795000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P2660', 'BRAND_P', 6, '1045000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P1597', 'BRAND_G', 18, '520000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P0968', 'BRAND_C', 6, '904000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P4075', 'BRAND_W', 6, '904000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P4057', 'BRAND_W', 4, '2095000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P4060', 'BRAND_W', 6, '2795000'),
# (1612339, '2019-01-01 00:00:00', 18055, 'Jakarta Selatan', 'DKI Jakarta', 'P4009', 'BRAND_W', 6, '1045000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P1306', 'BRAND_F', 8, '1325000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P1305', 'BRAND_F', 4, '1325000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P1307', 'BRAND_F', 8, '1325000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P0708', 'BRAND_C', 12, '520000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P0709', 'BRAND_C', 12, '520000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P0704', 'BRAND_C', 6, '1045000'),
# (1612342, '2019-01-01 00:00:00', 13963, 'Jakarta Utara', 'DKI Jakarta', 'P3599', 'BRAND_S', 4, '2095000'),
# (1612345, '2019-01-01 00:00:00', 17450, 'Bogor', 'Jawa Barat', 'P0327', 'BRAND_B', 6, '2322000'),
# (1612369, '2019-01-01 00:00:00', 17450, 'Bogor', 'Jawa Barat', 'P1742', 'BRAND_H', 402, '688000'),
# (1612369, '2019-01-01 00:00:00', 17450, 'Bogor', 'Jawa Barat', 'P1741', 'BRAND_H', 378, '1136000');
# Out:
#  * sqlite://
# 38 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO
#     sales_retail_2019
# VALUES
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P0517', 'BRAND_B', 72, '383000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2707', 'BRAND_P', 72, '383000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2928', 'BRAND_R', 12, '2235000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P3362', 'BRAND_S', 96, '236000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2806', 'BRAND_P', 48, '590000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P0525', 'BRAND_B', 96, '520000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P3412', 'BRAND_S', 16, '1325000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2946', 'BRAND_R', 12, '2445000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2935', 'BRAND_R', 32, '1325000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P1813', 'BRAND_I', 48, '660000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P0792', 'BRAND_C', 48, '660000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P0491', 'BRAND_B', 48, '450000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P1469', 'BRAND_F', 16, '1199000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2866', 'BRAND_R', 6, '1045000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2494', 'BRAND_P', 40, '904000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P4059', 'BRAND_W', 12, '1955000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P2325', 'BRAND_N', 48, '604000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P0255', 'BRAND_A', 160, '520000'),
# (1612372, '2019-01-01 00:00:00', 17511, 'Tangerang', 'Banten', 'P4009', 'BRAND_W', 32, '904000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1685', 'BRAND_H', 12, '747000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1679', 'BRAND_H', 12, '747000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P2964', 'BRAND_R', 4, '1325000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P0116', 'BRAND_A', 6, '747000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1800', 'BRAND_H', 4, '1640000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1684', 'BRAND_H', 24, '747000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P4025', 'BRAND_W', 4, '1325000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P3006', 'BRAND_R', 6, '1745000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P3132', 'BRAND_S', 6, '1745000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P0791', 'BRAND_C', 3, '1745000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1945', 'BRAND_K', 4, '1325000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1251', 'BRAND_E', 4, '1500000'),
# (1612375, '2019-01-01 00:00:00', 17091, 'Tangerang', 'Banten', 'P1683', 'BRAND_H', 12, '747000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P0041', 'BRAND_A', 12, '310000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P2760', 'BRAND_P', 12, '590000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P1329', 'BRAND_F', 12, '450000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P1700', 'BRAND_H', 24, '240000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P2641', 'BRAND_P', 8, '695000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P3484', 'BRAND_S', 6, '800000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P3122', 'BRAND_S', 6, '800000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P0040', 'BRAND_A', 12, '310000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P0931', 'BRAND_C', 4, '1395000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P2575', 'BRAND_P', 12, '520000'),
# (1612378, '2019-01-01 00:00:00', 17470, 'Jakarta Pusat', 'DKI Jakarta', 'P0117', 'BRAND_A', 4, '2795000'),
# (1612381, '2019-01-01 00:00:00', 17616, 'Surabaya', 'Jawa Timur', 'P4009', 'BRAND_W', 128, '904000'),
# (1612384, '2019-01-01 00:00:00', 15649, 'Malang', 'Jawa Timur', 'P0784', 'BRAND_C', 120, '1500000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P0449', 'BRAND_B', 6, '1325000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P2881', 'BRAND_R', 6, '1325000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P2594', 'BRAND_P', 10, '1325000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P1600', 'BRAND_G', 4, '1325000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P2086', 'BRAND_L', 4, '590000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P2103', 'BRAND_L', 6, '590000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P2089', 'BRAND_L', 6, '590000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P0515', 'BRAND_B', 5, '590000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P0535', 'BRAND_B', 6, '590000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P0029', 'BRAND_A', 12, '310000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P3362', 'BRAND_S', 12, '310000'),
# (1612387, '2019-01-01 00:00:00', 17228, 'Bogor', 'Jawa Barat', 'P3409', 'BRAND_S', 12, '310000');
# Out:
#  * sqlite://
# 57 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO
#     sales_retail_2019
# VALUES
# (1612390, '2019-01-01 00:00:00', 12681, 'Makassar', 'Sulawesi Selatan', 'P1867', 'BRAND_J', 12, '520000'),
# (1612390, '2019-01-01 00:00:00', 12681, 'Makassar', 'Sulawesi Selatan', 'P3388', 'BRAND_S', 10, '450000'),
# (1612390, '2019-01-01 00:00:00', 12681, 'Makassar', 'Sulawesi Selatan', 'P3082', 'BRAND_R', 18, '1045000'),
# (1612390, '2019-01-01 00:00:00', 12681, 'Makassar', 'Sulawesi Selatan', 'P
'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P0132', 'BRAND_A', 24, '205000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P2761', 'BRAND_P', 12, '590000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P2097', 'BRAND_L', 10, '590000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P2086', 'BRAND_L', 10, '590000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P1679', 'BRAND_H', 12, '747000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P1685', 'BRAND_H', 12, '747000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P1684', 'BRAND_H', 12, '747000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P1805', 'BRAND_H', 4, '1395000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P3006', 'BRAND_R', 6, '1745000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P0791', 'BRAND_C', 3, '1745000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P3699', 'BRAND_T', 10, '450000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P2098', 'BRAND_L', 10, '590000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P3692', 'BRAND_T', 15, '1500000'),
# (1612396, '2019-01-01 00:00:00', 17735, 'Malang', 'Jawa Timur', 'P2987', 'BRAND_R', 12, '450000');
# Out:
#  * sqlite://
# 91 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO
#     sales_retail_2019
# VALUES
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P2900', 'BRAND_R', 2, '1045000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1683', 'BRAND_H', 5, '747000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1685', 'BRAND_H', 3, '747000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1678', 'BRAND_H', 2, '747000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1679', 'BRAND_H', 5, '747000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1805', 'BRAND_H', 4, '1395000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1802', 'BRAND_H', 2, '1640000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P4195', 'BRAND_Z', 2, '450000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P4078', 'BRAND_W', 3, '590000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P4069', 'BRAND_W', 3, '450000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P3052', 'BRAND_R', 2, '450000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P0122', 'BRAND_A', 2, '590000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P3128', 'BRAND_S', 4, '450000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P0798', 'BRAND_C', 3, '747000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1742', 'BRAND_H', 3, '590000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1305', 'BRAND_F', 2, '1325000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1307', 'BRAND_F', 2, '1325000'),
# (1612402, '2019-01-01 00:00:00', 16059, 'Jakarta Utara', 'DKI Jakarta', 'P1306', 'BRAND_F', 2, '1325000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1805', 'BRAND_H', 4, '1395000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P3006', 'BRAND_R', 6, '1745000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1800', 'BRAND_H', 4, '1640000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1656', 'BRAND_G', 4, '1325000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P3132', 'BRAND_S', 3, '1745000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P0366', 'BRAND_B', 12, '904000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P0875', 'BRAND_C', 12, '534000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1318', 'BRAND_F', 4, '1325000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1319', 'BRAND_F', 4, '1325000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1309', 'BRAND_F', 6, '1045000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2094', 'BRAND_L', 10, '590000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2098', 'BRAND_L', 10, '590000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2097', 'BRAND_L', 10, '590000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P0029', 'BRAND_A', 24, '310000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2793', 'BRAND_P', 6, '747000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2794', 'BRAND_P', 6, '747000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2792', 'BRAND_P', 6, '747000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2115', 'BRAND_M', 24, '159000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P2803', 'BRAND_P', 3, '6312000'),
# (1612405, '2019-01-01 00:00:00', 12567, 'Makassar', 'Sulawesi Selatan', 'P1034', 'BRAND_D', 9, '2095000'),
# (1612408, '2019-01-01 00:00:00', 17720, 'Bogor', 'Jawa Barat', 'P0791', 'BRAND_C', 24, '1500000'),
# (1612411, '2019-01-01 00:00:00', 15018, 'Jakarta Selatan', 'DKI Jakarta', 'P2968', 'BRAND_R', 4, '4475000'),
# (1612411, '2019-01-01 00:00:00', 15018, 'Jakarta Selatan', 'DKI Jakarta', 'P1210', 'BRAND_E', 1, '5245000'),
# (1612411, '2019-01-01 00:00:00', 15018, 'Jakarta Selatan', 'DKI Jakarta', 'P3069', 'BRAND_R', 6, '1045000'),
# (1612411, '2019-01-01 00:00:00', 15018, 'Jakarta Selatan', 'DKI Jakarta', 'P3448', 'BRAND_S', 4, '1325000'),
# (1612411, '2019-01-01 00:00:00', 15018, 'Jakarta Selatan', 'DKI Jakarta', 'P2793', 'BRAND_P', 6, '747000'),
# (1612414, '2019-01-01 00:00:00', 14344, 'Jakarta Selatan', 'DKI Jakarta', 'P1240', 'BRAND_E', 3, '2095000'),
# (1612417, '2019-01-01 00:00:00', 12971, 'Jakarta Pusat', 'DKI Jakarta', 'P2489', 'BRAND_P', 12, '1045000'),
# (1612417, '2019-01-01 00:00:00', 12971, 'Jakarta Pusat', 'DKI Jakarta', 'P0804', 'BRAND_C', 24, '310000'),
# (1612417, '2019-01-01 00:00:00', 12971, 'Jakarta Pusat', 'DKI Jakarta', 'P0802', 'BRAND_C', 12, '310000'),
# (1612417, '2019-01-01 00:00:00', 12971, 'Jakarta Pusat', 'DKI Jakarta', 'P3071', 'BRAND_R', 6, '904000'),
# (1612417, '2019-01-01 00:00:00', 12971, 'Jakarta Pusat', 'DKI Jakarta', 'P0826', 'BRAND_C', 36, '159000'),
# (1612417, '2019-01-01 00:00:00', 12971, 'Jakarta Pusat', 'DKI Jakarta', 'P0829', 'BRAND_C', 36, '159000'),
# (1612429, '2019-01-01 00:00:00', 15838, 'Jakarta Utara', 'DKI Jakarta', 'P2877', 'BRAND_R', 150, '660000'),
# (1612429, '2019-01-01 00:00:00', 15838, 'Jakarta Utara', 'DKI Jakarta', 'P3744', 'BRAND_T', 100, '660000'),
# (1612429, '2019-01-01 00:00:00', 15838, 'Jakarta Utara', 'DKI Jakarta', 'P1902', 'BRAND_J', 300, '590000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P3822', 'BRAND_V', 36, '145000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P3660', 'BRAND_S', 12, '2987000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P3665', 'BRAND_S', 16, '2095000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P2329', 'BRAND_N', 12, '2987000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P4009', 'BRAND_W', 32, '904000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P3830', 'BRAND_V', 24, '1745000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P2923', 'BRAND_R', 6, '3844000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1702', 'BRAND_H', 24, '310000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P2946', 'BRAND_R', 4, '2795000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P3828', 'BRAND_V', 8, '3844000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P3442', 'BRAND_S', 24, '590000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1699', 'BRAND_H', 36, '383000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P2157', 'BRAND_M', 8, '1045000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1741', 'BRAND_H', 40, '904000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P0893', 'BRAND_C', 36, '198000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P0934', 'BRAND_C', 4, '1745000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P4195', 'BRAND_Z', 36, '450000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P0935', 'BRAND_C', 4, '1920000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P0063', 'BRAND_A', 16, '1045000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1830', 'BRAND_I', 4, '2987000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P2302', 'BRAND_N', 48, '904000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1742', 'BRAND_H', 80, '520000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1838', 'BRAND_I', 2, '2987000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P1735', 'BRAND_H', 12, '590000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P4057', 'BRAND_W', 16, '1745000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P4075', 'BRAND_W', 12, '904000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P2489', 'BRAND_P', 80, '904000'),
# (1612453, '2019-01-01 00:00:00', 14733, 'Jakarta Pusat', 'DKI Jakarta', 'P0887', 'BRAND_C', 48, '975000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', 'P1990', 'BRAND_L', 24, '590000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', 'P1868', 'BRAND_J', 6, '1500000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', 'P1867', 'BRAND_J', 24, '520000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', 'P0491', 'BRAND_B', 12, '450000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', 'P2880', 'BRAND_R', 24, '450000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', 'P3189', 'BRAND_S', 24, '159000'),
# (1612468, '2019-01-01 00:00:00', 17017, 'Jakarta Selatan', 'DKI Jakarta', '
'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P0237', 'BRAND_A', 6, '450000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P2880', 'BRAND_R', 1, '450000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P1242', 'BRAND_E', 2, '1500000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P2564', 'BRAND_P', 1, '2375000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P0624', 'BRAND_B', 1, '1325000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P1337', 'BRAND_F', 1, '1150000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P1475', 'BRAND_F', 3, '747000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P0167', 'BRAND_A', 1, '1325000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P0170', 'BRAND_A', 1, '1325000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P0171', 'BRAND_A', 1, '1325000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P2755', 'BRAND_P', 1, '1325000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P1679', 'BRAND_H', 4, '747000'),
# (1612960, '2019-01-01 00:00:00', 17897, 'Surakarta', 'Jawa Tengah', 'P1678', 'BRAND_H', 2, '747000');
# Out:
#  * sqlite://
# 534 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO
#     sales_retail_2019
# VALUES
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P1560', 'BRAND_G', 3, '1745000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P0840', 'BRAND_C', 12, '310000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P3475', 'BRAND_S', 12, '345000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P4009', 'BRAND_W', 6, '1045000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P4033', 'BRAND_W', 6, '904000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P1184', 'BRAND_E', 10, '310000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P3723', 'BRAND_T', 2, '3144000'),
# (1612966, '2019-01-01 00:00:00', 15081, 'Tangerang', 'Banten', 'P3071', 'BRAND_R', 6, '904000'),
# (1612972, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P4059', 'BRAND_W', 408, '1685000'),
# (1612972, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P3820', 'BRAND_U', 30, '6956000'),
# (1612972, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0931', 'BRAND_C', 972, '821000'),
# (1612972, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0413', 'BRAND_B', 972, '821000'),
# (1612972, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P3912', 'BRAND_V', 408, '2245000'),
# (1612975, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P4059', 'BRAND_W', 48, '1685000'),
# (1612975, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0931', 'BRAND_C', 36, '821000'),
# (1612975, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0413', 'BRAND_B', 36, '821000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P2320', 'BRAND_N', 23, '3474000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P2155', 'BRAND_M', 208, '1363000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0931', 'BRAND_C', 1008, '821000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0413', 'BRAND_B', 1008, '821000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P3894', 'BRAND_V', 10, '18482000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P3912', 'BRAND_V', 600, '2245000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P0935', 'BRAND_C', 160, '1370000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P4059', 'BRAND_W', 600, '1685000'),
# (1612978, '2019-01-01 00:00:00', 18102, 'Yogyakarta', 'Yogyakarta', 'P1671', 'BRAND_H', 72, '11454000'),
# (1612993, '2019-01-01 00:00:00', 15024, 'Yogyakarta', 'Yogyakarta', 'P0220', 'BRAND_A', 24, '695000'),
# (1612996, '2019-01-01 00:00:00', 16365, 'Jakarta Selatan', 'DKI Jakarta', 'P0811', 'BRAND_C', 1, '1745000'),
# (1612996, '2019-01-01 00:00:00', 16365, 'Jakarta Selatan', 'DKI Jakarta', 'P1923', 'BRAND_K', 1, '3494000'),
# (1612996, '2019-01-01 00:00:00', 16365, 'Jakarta Selatan', 'DKI Jakarta', 'P2377', 'BRAND_O', 1, '2987000'),
# (1612996, '2019-01-01 00:00:00', 16365, 'Jakarta Selatan', 'DKI Jakarta', 'P1105', 'BRAND_D', 1, '2795000'),
# (1612996, '2019-01-01 00:00:00', 16365, 'Jakarta Selatan', 'DKI Jakarta', 'P3177', 'BRAND_S', 1, '2375000'),
# (1612996, '2019-01-01 00:00:00', 16365, 'Jakarta Selatan', 'DKI Jakarta', 'P4185', 'BRAND_Z', 96, '383000'),
# (1613002, '2019-01-02 00:00:00', 17870, 'Surakarta', 'Jawa Tengah', 'P0063', 'BRAND_A', 128, '904000'),
# (1613005, '2019-01-02 00:00:00', 14821, 'Yogyakarta', 'Yogyakarta', 'P1679', 'BRAND_H', 12, '747000'),
# (1613005, '2019-01-02 00:00:00', 14821, 'Yogyakarta', 'Yogyakarta', 'P0063', 'BRAND_A', 8, '1045000'),
# (1613008, '2019-01-02 00:00:00', 16863, 'Jakarta Timur', 'DKI Jakarta', '
'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1508', 'BRAND_G', 24, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0356', 'BRAND_B', 24, '604000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P3250', 'BRAND_S', 4, '310000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0126', 'BRAND_A', 12, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1083', 'BRAND_D', 36, '695000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0304', 'BRAND_B', 1, '904000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0305', 'BRAND_B', 1, '904000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0309', 'BRAND_B', 1, '904000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0300', 'BRAND_B', 2, '904000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1738', 'BRAND_H', 4, '450000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1734', 'BRAND_H', 4, '450000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P3507', 'BRAND_S', 4, '450000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P3699', 'BRAND_T', 8, '450000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0010', 'BRAND_S', 4, '1045000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P2442', 'BRAND_P', 2, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0128', 'BRAND_A', 4, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P2443', 'BRAND_P', 6, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0132', 'BRAND_A', 6, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P2445', 'BRAND_P', 4, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P2444', 'BRAND_P', 4, '205000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0241', 'BRAND_A', 6, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0164', 'BRAND_A', 2, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P2770', 'BRAND_P', 8, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1813', 'BRAND_I', 7, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0898', 'BRAND_C', 12, '695000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1674', 'BRAND_H', 12, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P1797', 'BRAND_H', 8, '747000'),
# (1613077, '2019-01-02 00:00:00', 14796, 'Yogyakarta', 'Yogyakarta', 'P0792', 'BRAND_C', 8, '747000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P4132', 'BRAND_W', 25, '159000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P3850', 'BRAND_V', 25, '159000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P0538', 'BRAND_B', 25, '159000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P2494', 'BRAND_P', 6, '1045000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P2489', 'BRAND_P', 6, '1045000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P2135', 'BRAND_M', 6, '1045000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P2134', 'BRAND_M', 6, '1045000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P1266', 'BRAND_F', 4, '1325000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P3700', 'BRAND_T', 5, '1640000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P3747', 'BRAND_T', 12, '450000'),
# (1613080, '2019-01-02 00:00:00', 12441, 'Makassar', 'Sulawesi Selatan', 'P2803', 'BRAND_P', 1, '6312000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0809', 'BRAND_C', 2, '2987000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0170', 'BRAND_A', 1, '1325000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0305', 'BRAND_B', 2, '904000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0304', 'BRAND_B', 2, '904000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P3261', 'BRAND_S', 2, '450000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0300', 'BRAND_B', 12, '904000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P1867', 'BRAND_J', 12, '520000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P1511', 'BRAND_G', 4, '450000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P2763', 'BRAND_P', 4, '590000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0307', 'BRAND_B', 3, '1150000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0306', 'BRAND_B', 3, '1150000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P3254', 'BRAND_S', 6, '450000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P0075', 'BRAND_A', 2, '747000'),
# (1613083, '2019-01-02 00:00:00', 14901, 'Jakarta Pusat', 'DKI Jakarta', 'P1868', 'BRAND_J', 8, '1500000'),
# (1613095, '2019-01-02 00:00:00', 13199, 'Malang', 'Jawa Timur', 'P2281', 'BRAND_M', 384, '264000'),
# (1613095, '2019-01-02 00:00:00', 13199, 'Malang', 'Jawa Timur', 'P2227', 'BRAND_M', 16, '1745000'),
# (1613095, '2019-01-02 00:00:00', 13199, 'Malang', 'Jawa Timur', 'P1059', 'BRAND_D', 16, '1500000'),
# (1613095, '2019-01-02 00:00:00', 13199, 'Malang', 'Jawa Timur', 'P3348', 'BRAND_S', 36, '450000'),
# (1613101, '2019-01-02 00:00:00', 18229, 'Jakarta Selatan', 'DKI Jakarta', 'P3253', 'BRAND_S', 12, '1640000'),
# (1613101, '2019-01-02 00:00:00', 18229, 'Jakarta Selatan', 'DKI Jakarta', 'P0167', 'BRAND_A', 8, '1325000'),
# (1613101, '2019-01-02 00:00:00', 18229, 'Jakarta Selatan', 'DKI Jakarta', 'P3257', 'BRAND_S', 48, '1640000'),
# (1613122, '2019-01-02 00:00:00', 14032, 'Yogyakarta', 'Yogyakarta', '
'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P3510', 'BRAND_S', 16, '747000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P1550', 'BRAND_G', 8, '1395000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P1549', 'BRAND_G', 4, '2987000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P1118', 'BRAND_D', 10, '2375000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P1103', 'BRAND_D', 20, '2375000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P4025', 'BRAND_W', 12, '1325000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P1793', 'BRAND_H', 12, '450000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P3847', 'BRAND_V', 12, '450000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P2411', 'BRAND_P', 48, '113000'),
# (1613368, '2019-01-02 00:00:00', 14051, 'Jakarta Selatan', 'DKI Jakarta', 'P1800', 'BRAND_H', 24, '1640000'),
# (1613374, '2019-01-02 00:00:00', 16233, 'Surakarta', 'Jawa Tengah', 'P3828', 'BRAND_V', 8, '3844000'),
# (1613374, '2019-01-02 00:00:00', 16233, 'Surakarta', 'Jawa Tengah', 'P3413', 'BRAND_S', 4, '5245000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P0581', 'BRAND_B', 1, '3494000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1508', 'BRAND_G', 12, '747000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P2770', 'BRAND_P', 12, '747000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P3012', 'BRAND_R', 12, '590000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P3005', 'BRAND_R', 4, '904000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P2377', 'BRAND_O', 1, '2987000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1173', 'BRAND_E', 2, '240000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P0133', 'BRAND_A', 1, '159000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1685', 'BRAND_H', 1, '747000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1679', 'BRAND_H', 2, '747000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P0260', 'BRAND_A', 2, '79000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1770', 'BRAND_H', 1, '240000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1770', 'BRAND_H', 1, '240000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1767', 'BRAND_H', 1, '240000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1772', 'BRAND_H', 1, '240000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P1769', 'BRAND_H', 1, '240000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P0260', 'BRAND_A', 2, '79000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P0967', 'BRAND_C', 1, '695000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P2491', 'BRAND_P', 2, '1045000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P2492', 'BRAND_P', 4, '1045000'),
# (1613377, '2019-01-02 00:00:00', 16385, 'Jakarta Utara', 'DKI Jakarta', 'P2490', 'BRAND_P', 6, '1045000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1915', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1913', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1901', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1904', 'BRAND_J', 200, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1890', 'BRAND_J', 200, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1900', 'BRAND_J', 200, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1912', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1905', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1906', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1902', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1907', 'BRAND_J', 100, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1897', 'BRAND_J', 200, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2093', 'BRAND_L', 1, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P3637', 'BRAND_S', 3, '450000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2103', 'BRAND_L', 3, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2098', 'BRAND_L', 3, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2094', 'BRAND_L', 1, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2097', 'BRAND_L', 3, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2093', 'BRAND_L', 4, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2091', 'BRAND_L', 3, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2086', 'BRAND_L', 3, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2094', 'BRAND_L', 2, '590000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2528', 'BRAND_P', 2, '450000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2938', 'BRAND_R', 3, '450000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P3627', 'BRAND_S', 3, '1045000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P3127', 'BRAND_S', 3, '1045000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2933', 'BRAND_R', 3, '1045000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P1250', 'BRAND_E', 12, '695000'),
# (1613380, '2019-01-02 00:00:00', 15032, 'Jakarta Selatan', 'DKI Jakarta', 'P2738', 'BRAND_P', 3, '1045000');
# Out:
#  * sqlite://
# 1068 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO
#     sales_retail_2019
# VALUES
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1118', 'BRAND_D', 1, '2795000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1114', 'BRAND_D', 2, '2795000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4057', 'BRAND_W', 2, '2095000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4060', 'BRAND_W', 2, '2795000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4027', 'BRAND_W', 6, '450000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0541', 'BRAND_B', 6, '450000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0544', 'BRAND_B', 6, '450000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1277', 'BRAND_F', 1, '3494000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1276', 'BRAND_F', 1, '2987000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3371', 'BRAND_S', 3, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2897', 'BRAND_R', 6, '590000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0840', 'BRAND_C', 6, '310000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2372', 'BRAND_O', 3, '310000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4071', 'BRAND_W', 2, '1045000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4075', 'BRAND_W', 2, '904000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3412', 'BRAND_S', 1, '1500000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2568', 'BRAND_P', 2, '1045000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0065', 'BRAND_A', 2, '2987000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2576', 'BRAND_P', 4, '2375000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1319', 'BRAND_F', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1318', 'BRAND_F', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1320', 'BRAND_F', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2960', 'BRAND_R', 6, '590000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4069', 'BRAND_W', 3, '450000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3583', 'BRAND_S', 12, '159000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1279', 'BRAND_F', 12, '159000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0679', 'BRAND_C', 12, '159000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0668', 'BRAND_C', 12, '159000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0672', 'BRAND_C', 12, '159000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3053', 'BRAND_R', 1, '1500000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3875', 'BRAND_V', 3, '450000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2575', 'BRAND_P', 3, '520000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0169', 'BRAND_A', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0171', 'BRAND_A', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0170', 'BRAND_A', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0167', 'BRAND_A', 3, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3132', 'BRAND_S', 3, '1745000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4025', 'BRAND_W', 3, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3006', 'BRAND_R', 2, '1745000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1805', 'BRAND_H', 2, '1395000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0366', 'BRAND_B', 2, '904000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1285', 'BRAND_F', 2, '1045000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1251', 'BRAND_E', 2, '1500000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2964', 'BRAND_R', 2, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1945', 'BRAND_K', 2, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2594', 'BRAND_P', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P0449', 'BRAND_B', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P1600', 'BRAND_G', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2881', 'BRAND_R', 1, '1325000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2566', 'BRAND_P', 4, '590000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3075', 'BRAND_R', 1, '2795000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P3745', 'BRAND_T', 1, '747000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P2325', 'BRAND_N', 2, '747000'),
# (1613383, '2019-01-02 00:00:00', 16713, 'Yogyakarta', 'Yogyakarta', 'P4179', 'BRAND_Y', 2, '604000');
# Out:
#  * sqlite://
# 54 rows affected.
# []

# %% [markdown]
# ## Fungsi di SQL

# %% [markdown]
# #### [Fungsi Skalar Matematika - ABS()](https://academy.dqlab.id/main/livecode/171/336/1606?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   Semester1,
#   Semester2,
#   ABS(MarkGrowth) as MarkGrowth
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(1, 'Jose', 'Mohit', 64.55, 72.6, 8.05),
#  (2, 'Lala', 'Karlina', 72.85, 65.35, 7.5),
#  (3, 'Sultan', 'Hadi', 45.32, 50.25, 4.93),
#  (4, 'Jaya', 'Usman', 86.73, 77.4, 9.33),
#  (5, 'Anjali', 'Wijaya', 92.25, 90.75, 1.5)]

# %% [markdown]
# #### [Fungsi Skalar Matematika - CEILING()](https://academy.dqlab.id/main/livecode/171/336/1607?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   CEILING(Semester1) as Semester1,
#   CEILING(Semester2) as Semester2,
#   MarkGrowth
# FROM students;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: CEILING
# [SQL: SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   CEILING(Semester1) as Semester1,
#   CEILING(Semester2) as Semester2,
#   MarkGrowth
# FROM students;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### [Fungsi Skalar Matematika - FLOOR()](https://academy.dqlab.id/main/livecode/171/336/1608?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   FLOOR(Semester1) as Semester1,
#   FLOOR(Semester2) as Semester2,
#   MarkGrowth
# FROM students;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: FLOOR
# [SQL: SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   FLOOR(Semester1) as Semester1,
#   FLOOR(Semester2) as Semester2,
#   MarkGrowth
# FROM students;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### [Fungsi Skalar Matematika - ROUND()](https://academy.dqlab.id/main/livecode/171/336/1609?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   ROUND(Semester1,1) as Semester1,
#   ROUND(Semester2,0) as Semester2,
#   MarkGrowth
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(1, 'Jose', 'Mohit', 64.5, 73.0, -8.05),
#  (2, 'Lala', 'Karlina', 72.8, 65.0, 7.5),
#  (3, 'Sultan', 'Hadi', 45.3, 50.0, -4.93),
#  (4, 'Jaya', 'Usman', 86.7, 77.0, 9.33),
#  (5, 'Anjali', 'Wijaya', 92.3, 91.0, 1.5)]

# %% [markdown]
# #### [Fungsi Skalar Matematika - SQRT( )](https://academy.dqlab.id/main/livecode/171/336/1610?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   SQRT(Semester1) as Semester1,
#   Semester2,
#   MarkGrowth
# FROM students;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: SQRT
# [SQL: SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   SQRT(Semester1) as Semester1,
#   Semester2,
#   MarkGrowth
# FROM students;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### [Tugas Praktek](https://academy.dqlab.id/main/livecode/171/336/1611?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   MOD(Semester1,2) as Semester1,
#   Semester2,
#   EXP(MarkGrowth)
# FROM students;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: MOD
# [SQL: SELECT
#   StudentID,
#   FirstName,
#   LastName,
#   MOD(Semester1,2) as Semester1,
#   Semester2,
#   EXP(MarkGrowth)
# FROM students;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## Fungsi Text di SQL

# %% [markdown]
# #### [Fungsi Text - CONCAT( )](https://academy.dqlab.id/main/livecode/171/337/1613?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   CONCAT(FirstName, LastName) as Name,
#   Semester1,
#   Semester2,
#   MarkGrowth
# FROM students;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: CONCAT
# [SQL: SELECT
#   StudentID,
#   CONCAT(FirstName, LastName) as Name,
#   Semester1,
#   Semester2,
#   MarkGrowth
# FROM students;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### [Fungsi Text - SUBSTRING_INDEX( )](https://academy.dqlab.id/main/livecode/171/337/1634?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   SUBSTRING_INDEX(Email,'@',1) as Name
# FROM students;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: SUBSTRING_INDEX
# [SQL: SELECT
#   StudentID,
#   SUBSTRING_INDEX(Email,'@',1) as Name
# FROM students;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### [Fungsi Text - SUBSTR( )](https://academy.dqlab.id/main/livecode/171/337/1635?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   SUBSTR(FirstName, 2, 3) as Initial
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(1, 'ose'), (2, 'ala'), (3, 'ult'), (4, 'aya'), (5, 'nja')]

# %% [markdown]
# #### [Fungsi Text - LENGTH( )](https://academy.dqlab.id/main/livecode/171/337/1636?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   FirstName,
#   LENGTH(FirstName) as Total_Char
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(1, 'Jose', 4),
#  (2, 'Lala', 4),
#  (3, 'Sultan', 6),
#  (4, 'Jaya', 4),
#  (5, 'Anjali', 6)]

# %% [markdown]
# #### [Fungsi Text - REPLACE( )](https://academy.dqlab.id/main/livecode/171/337/1637?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   Email,
#   REPLACE(Email, 'yahoo', 'gmail') as New_Email
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(1, 'Jose_Mohit@gmail.com', 'Jose_Mohit@gmail.com'),
#  (2, 'lala_karlina@yahoo.com', 'lala_karlina@gmail.com'),
#  (3, 'Sultan_Hadi@gmail.com', 'Sultan_Hadi@gmail.com'),
#  (4, 'jaya_usman@yahoo.com', 'jaya_usman@gmail.com'),
#  (5, 'anjali_wijaya@yahoo.com', 'anjali_wijaya@gmail.com')]

# %% [markdown]
# #### [Tugas Praktek](https://academy.dqlab.id/main/livecode/171/337/1638?pr=0)

# %%
# %%sql
#
# SELECT
#   StudentID,
#   UPPER(FirstName) as FirstName,
#   LOWER(LastName) as LastName
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(1, 'JOSE', 'mohit'),
#  (2, 'LALA', 'karlina'),
#  (3, 'SULTAN', 'hadi'),
#  (4, 'JAYA', 'usman'),
#  (5, 'ANJALI', 'wijaya')]

# %% [markdown]
# ## Fungsi Aggregate dan Group By

# %% [markdown]
# #### [Fungsi Aggregate - SUM()](https://academy.dqlab.id/main/livecode/171/340/1640?pr=0)

# %%
# %%sql
#
# SELECT
#   SUM(Semester1) as Total_1,
#   SUM(Semester2) as Total_2
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(361.7, 356.35)]

# %% [markdown]
# #### [Fungsi Aggregate - COUNT()](https://academy.dqlab.id/main/livecode/171/340/1641?pr=0)

# %%
# %%sql
#
# SELECT
#   COUNT(FirstName) as Total_Student
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(5,)]

# %% [markdown]
# #### [Fungsi Aggregate - AVG( )](https://academy.dqlab.id/main/livecode/171/340/1642?pr=0)

# %%
# %%sql
#
# SELECT
#   AVG(Semester1) as AVG_1,
#   AVG(Semester2) as AVG_2
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(72.34, 71.27000000000001)]

# %% [markdown]
# #### [Tugas Praktek](https://academy.dqlab.id/main/livecode/171/340/1643?pr=0)

# %%
# %%sql
#
# SELECT
#   MIN(Semester1) AS Min1,
#   MAX(Semester1) AS Max1,
#   MIN(Semester2) AS Min2,
#   MAX(Semester2) AS Max2
# FROM students;
# Out:
#  * sqlite://
# Done.
# [(45.32, 92.25, 50.25, 90.75)]

# %% [markdown]
# #### [Group by Single Column](https://academy.dqlab.id/main/livecode/171/340/1645?pr=0)

# %%
# %%sql
# # saya hanya ngambil 2.200 baris data dari total 384.319
# SELECT COUNT(order_id) as jml_id
# FROM sales_retail_2019;
# Out:
#  * sqlite://
# Done.
# [(2200,)]

# %%
# %%sql
#
# SELECT
#   province,
#   COUNT(DISTINCT order_id) as total_order,
#   SUM(item_price) as total_price
# FROM sales_retail_2019
# GROUP BY province;
# Out:
#  * sqlite://
# Done.
# [('Bali', 2, 53025000.0),
#  ('Banten', 6, 85380000),
#  ('DKI Jakarta', 64, 1113250000.0),
#  ('Jawa Barat', 18, 294817000.0),
#  ('Jawa Tengah', 8, 227475000),
#  ('Jawa Timur', 9, 125168000),
#  ('Sulawesi Selatan', 3, 78988000),
#  ('Sumatra Barat', 1, 7733000),
#  ('Yogyakarta', 15, 364719000),
#  ('unknown', 1, 31743000)]

# %% [markdown]
# #### [Group by Multiple Column](https://academy.dqlab.id/main/livecode/171/340/1646?pr=0)

# %%
# %%sql
#
# SELECT
#   province,
#   brand,
#   COUNT(DISTINCT order_id) as total_order,
#   SUM(item_price) as total_price
# FROM sales_retail_2019
# GROUP BY
#   province,
#   brand;
# Out:
#  * sqlite://
# Done.
# [('Bali', 'BRAND_A', 2, 1145000),
#  ('Bali', 'BRAND_B', 1, 10490000),
#  ('Bali', 'BRAND_F', 1, 2825000),
#  ('Bali', 'BRAND_G', 1, 747000),
#  ('Bali', 'BRAND_I', 1, 2987000),
#  ('Bali', 'BRAND_K', 1, 310000),
#  ('Bali', 'BRAND_M', 2, 5637000),
#  ('Bali', 'BRAND_P', 2, 12624000),
#  ('Bali', 'BRAND_R', 2, 3870000.0),
#  ('Bali', 'BRAND_S', 2, 10895000),
#  ('Bali', 'BRAND_T', 1, 1495000),
#  ('Banten', 'BRAND_A', 5, 2757000),
#  ('Banten', 'BRAND_B', 1, 1353000),
#  ('Banten', 'BRAND_C', 6, 9231000),
#  ('Banten', 'BRAND_E', 2, 1810000),
#  ('Banten', 'BRAND_F', 2, 2244000),
#  ('Banten', 'BRAND_G', 3, 4721000),
#  ('Banten', 'BRAND_H', 4, 7757000),
#  ('Banten', 'BRAND_I', 1, 660000),
#  ('Banten', 'BRAND_J', 2, 3410000),
#  ('Banten', 'BRAND_K', 1, 1325000),
#  ('Banten', 'BRAND_L', 3, 3093000),
#  ('Banten', 'BRAND_M', 2, 1057000),
#  ('Banten', 'BRAND_N', 1, 604000),
#  ('Banten', 'BRAND_P', 2, 5689000),
#  ('Banten', 'BRAND_R', 6, 17407000),
# ...

# %% [markdown]
# #### [Fungsi Aggregate dengan Grouping](https://academy.dqlab.id/main/livecode/171/340/1647?pr=0)

# %%
# %%sql
#
# SELECT
#     province,
#     COUNT(DISTINCT order_id) AS total_unique_order,
#     SUM(item_price) AS revenue
# FROM
#     sales_retail_2019
# GROUP BY
#     province;
# Out:
#  * sqlite://
# Done.
# [('Bali', 2, 53025000.0),
#  ('Banten', 6, 85380000),
#  ('DKI Jakarta', 64, 1113250000.0),
#  ('Jawa Barat', 18, 294817000.0),
#  ('Jawa Tengah', 8, 227475000),
#  ('Jawa Timur', 9, 125168000),
#  ('Sulawesi Selatan', 3, 78988000),
#  ('Sumatra Barat', 1, 7733000),
#  ('Yogyakarta', 15, 364719000),
#  ('unknown', 1, 31743000)]

# %% [markdown]
# #### [Tugas Praktek](https://academy.dqlab.id/main/livecode/171/340/1650?pr=0)

# %%
# %%sql
#
# SELECT MONTH(order_date) AS order_month, SUM(item_price) AS total_price,
# CASE
#     WHEN SUM(item_price) >= 30000000000 THEN 'Target Achieved'
#     WHEN SUM(item_price) <= 25000000000 THEN 'Less Performed'
#     ELSE 'Follow Up'
# END as remark
# FROM sales_retail_2019
# GROUP BY MONTH(order_date);
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such function: MONTH
# [SQL: SELECT MONTH(order_date) AS order_month, SUM(item_price) AS total_price,
# CASE
#     WHEN SUM(item_price) >= 30000000000 THEN 'Target Achieved'
#     WHEN SUM(item_price) <= 25000000000 THEN 'Less Performed'
#     ELSE 'Follow Up'
# END as remark
# FROM sales_retail_2019
# GROUP BY MONTH(order_date);]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## Mini Project

# %% [markdown]
# #### [Proyek Pekerjaan - Analisis Penjualan Part 1](https://academy.dqlab.id/main/livecode/171/341/1652?pr=0)

# %%
# %%sql
#
# --1. Total jumlah seluruh penjualan (total/revenue).
# SELECT SUM(total) as total
# FROM tr_penjualan;
# Out:
#  * sqlite://
# Done.
# [(3271600,)]

# %%
# %%sql
#
# --2. Total quantity seluruh produk yang terjual.
# SELECT SUM(qty) as qty
# FROM tr_penjualan;
# Out:
#  * sqlite://
# Done.
# [(42,)]

# %%
# %%sql
#
# --3. Total quantity dan total revenue untuk setiap kode produk.
# SELECT kode_produk, SUM(qty) as qty, SUM(total) as total
# FROM tr_penjualan
# GROUP BY kode_produk;
# Out:
#  * sqlite://
# Done.
# [('prod-01', 6, 375000),
#  ('prod-02', 2, 110000),
#  ('prod-03', 3, 300000),
#  ('prod-04', 9, 360000),
#  ('prod-05', 4, 1000000),
#  ('prod-07', 1, 48000),
#  ('prod-08', 2, 31600),
#  ('prod-09', 6, 552000),
#  ('prod-10', 9, 495000)]

# %% [markdown]
# #### [Proyek Pekerjaan - Analisis Penjualan Part 2](https://academy.dqlab.id/main/livecode/171/341/1654?pr=0)

# %%
# %%sql
#
# -- 4. Rata - Rata total belanja per kode pelanggan.
# SELECT kode_pelanggan, AVG(total) as avg_total
# FROM tr_penjualan
# GROUP BY kode_pelanggan;
# Out:
#  * sqlite://
# Done.
# [('dqlabcust01', 156000.0),
#  ('dqlabcust02', 515800.0),
#  ('dqlabcust03', 181666.66666666666),
#  ('dqlabcust05', 139500.0),
#  ('dqlabcust07', 202125.0)]

# %%
# %%sql
#
# -- 5. Selain itu,  jangan lupa untuk menambahkan kolom baru dengan nama ‘kategori’ yang mengkategorikan total/revenue ke dalam 3 kategori: High: > 300K; Medium: 100K - 300K; Low: <100K.
# SELECT kode_transaksi,kode_pelanggan,no_urut,kode_produk, nama_produk, qty, total,
# CASE
#     WHEN total > 300000 THEN 'High'
#     WHEN total < 100000 THEN 'Low'
#     ELSE 'Medium'
# END as kategori
# FROM tr_penjualan;
# Out:
#  * sqlite://
# Done.
# [('tr-001', 'dqlabcust07', 1, 'prod-01', 'Kotak Pensil DQLab', 5, 312500, 'High'),
#  ('tr-001', 'dqlabcust07', 2, 'prod-03', 'Flash disk DQLab 32 GB', 1, 100000, 'Medium'),
#  ('tr-001', 'dqlabcust07', 3, 'prod-09', 'Buku Planner Agenda DQLab', 3, 276000, 'Medium'),
#  ('tr-001', 'dqlabcust07', 4, 'prod-04', 'Flashdisk DQLab 32 GB', 3, 120000, 'Medium'),
#  ('tr-002', 'dqlabcust01', 1, 'prod-03', 'Gift Voucher DQLab 100rb', 2, 200000, 'Medium'),
#  ('tr-002', 'dqlabcust01', 2, 'prod-10', 'Sticky Notes DQLab 500 sheets', 4, 220000, 'Medium'),
#  ('tr-002', 'dqlabcust01', 3, 'prod-07', 'Tas Travel Organizer DQLab', 1, 48000, 'Low'),
#  ('tr-003', 'dqlabcust03', 1, 'prod-02', 'Flashdisk DQLab 64 GB', 2, 110000, 'Medium'),
#  ('tr-004', 'dqlabcust03', 1, 'prod-10', 'Sticky Notes DQLab 500 sheets', 5, 275000, 'Medium'),
#  ('tr-004', 'dqlabcust03', 2, 'prod-04', 'Flashdisk DQLab 32 GB', 4, 160000, 'Medium'),
# ...
